# %% [markdown]
# # 1. Amount of respondents who have answered all of the questions:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Markdown as md
a= 89184
md(f'1. Amount of respondents who have answered all of the questions: {a}')
df = pd.read_csv('/Users/denistkachenko/Documents/survey_results_public.csv')
df2 = pd.read_csv('/Users/denistkachenko/Documents/survey_results_schema.csv')

# %%
md(f'# 1. Amount of respondents who have answered all of the questions: {a}')
# Out:
# # 1. Amount of respondents who have answered all of the questions: 89184

# %%
df2
# Out:
#        qid        qname                                           question  \
# 0    QID16           S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12     MetaInfo                                  Browser Meta Info
# 2   QID310         Q310  <div><span style="font-size:19px;"><strong>You...
# 3   QID312         Q120
# 4     QID1           S1  <span style="font-size:22px; font-family: aria...
# ..     ...          ...                                                ...
# 73  QID289  Knowledge_7  Waiting on answers to questions often causes i...
# 74  QID289  Knowledge_8  I feel like I have the tools and/or resources ...
# 75  QID290  Frequency_1  Needing help from people outside of your immed...
# 76  QID290  Frequency_2  Interacting with people outside of your immedi...
# 77  QID290  Frequency_3  Encountering knowledge silos (where one indivi...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# ...

# %%
#questions = set(df2.qname.unique()) & set(df.columns)
#df.dropna(subset=questions)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
test = df.loc[df['RemoteWork']== 'Remote']

# %%
test2 = df.dropna()
test2
# Out:
# Empty DataFrame
# ...

# %%
answer = df.loc[df['LanguageHaveWorkedWith'].str.contains('Python', na=False)].groupby('LanguageHaveWorkedWith')['ResponseId'].count()

# %%
answer.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 19959 entries, APL;Assembly;Bash/Shell (all shells);C#;C++;Clojure;JavaScript;Python;Rust to Python;Visual Basic (.Net)
# Series name: ResponseId
# Non-Null Count  Dtype
# --------------  -----
# 19959 non-null  int64
# dtypes: int64(1)
# memory usage: 311.9+ KB

# %%
df['Python'] = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
test3 = df.groupby(['Python', 'DevType'])['ResponseId'].count()
clean = df.dropna(subset='ConvertedCompYearly')
test4 = clean.groupby(['Python', 'Country'])['ConvertedCompYearly'].agg(['mean', 'median', 'max', 'min'])

# %%
test4.reset_index(inplace=True)

# %%
test4.loc[test4['Python']== True]
test4.drop('Python', axis=1, inplace=True)

# %%
test4.dropna(inplace=True)

# %%
test4
# Out:
#                                   Country          mean    median        max  \
# 0                             Afghanistan  1.546112e+06    1773.5  9203683.0
# 1                                 Albania  2.962307e+04    8685.0   139700.0
# 2                                 Algeria  1.136883e+04    9391.0    37776.0
# 3                                 Andorra  1.424292e+05  128507.5   289142.0
# 4                                  Angola  7.942000e+03    7942.0     7942.0
# ..                                    ...           ...       ...        ...
# 312  Venezuela, Bolivarian Republic of...  2.497353e+04   12000.0   100000.0
# 313                              Viet Nam  2.019187e+04   13401.0   107090.0
# 314                                 Yemen  8.373000e+03    9000.0    13323.0
# 315                                Zambia  1.305100e+04    9687.0    25228.0
# 316                              Zimbabwe  5.600000e+03    6000.0     7800.0
#
#          min
# 0      648.0
# 1       14.0
# ...

# %%
test2.groupby('LanguageHaveWorkedWith').count()
# Out:
# Empty DataFrame
# ...

# %%
test = df.groupby('RemoteWork')['ResponseId'].count()
test
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# In-person                               12113
# Remote                                  30566
# Name: ResponseId, dtype: int64

# %%
test3 = test3.to_frame()

# %%
test3.reset_index(inplace=True)

# %%
test3 = test3.loc[test3['Python']== True]

# %%
test3
# Out:
#     Python                                        DevType  ResponseId
# 33    True                            Academic researcher        1063
# 34    True                                     Blockchain         135
# 35    True                  Cloud infrastructure engineer         727
# 36    True                       Data or business analyst         559
# 37    True  Data scientist or machine learning specialist        1487
# 38    True                         Database administrator         109
# 39    True                                       Designer          85
# 40    True                              DevOps specialist         993
# 41    True                             Developer Advocate          90
# 42    True                           Developer Experience         162
# 43    True                          Developer, QA or test         348
# 44    True                            Developer, back-end        6087
# ...

# %%
plt.pie(test3['ResponseId'], 
        labels=test3['DevType'] ,
        autopct='%1.1f%%', 
        shadow=True, 
        startangle=90,
        radius=2,
        labeldistance=1.1,
        pctdistance=0.9,)
plt.show()

# %%
test4= df.nlargest(10, 'ConvertedCompYearly')

# %%
test4
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 53268       53269  I agree                     I am a developer by profession
# 77848       77849  I agree                     I am a developer by profession
# 66223       66224  I agree                     I am a developer by profession
# 28121       28122  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 55102       55103  I agree  I am not primarily a developer, but I write co...
# 80586       80587  I agree                     I am a developer by profession
# 83679       83680  I agree                     I am a developer by profession
# 47797       47798  I agree                     I am a developer by profession
# 88347       88348  I agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
test4['Status'] = np.select( [test4['ConvertedCompYearly'] > 100000, test4['ConvertedCompYearly'] < 100000], ['Rich', 'Poor'], default='Unknown')

# %%
test4['Status'].value_counts()
# Out:
# Rich    10
# Name: Status, dtype: int64

# %%
print(f'Mode: {round(df.WorkExp.mode()[0], 1)}')
# Out:
# Mode: 5.0

# %%
url='https://drive.google.com/file/d/0B6GhBwm5vaB2ekdlZW5WZnppb28/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/1w/5fknmcjj7_g7sfbf2lffwy1h0000gn/T/ipykernel_25484/1074791802.py in <module>
#       1 url='https://drive.google.com/file/d/0B6GhBwm5vaB2ekdlZW5WZnppb28/view?usp=sharing'
#       2 url='https://drive.google.com/uc?id=' + url.split('/')[-2]
# ----> 3 df = pd.read_csv(url)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#work with markdown
import re

txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
print(x)
