# %% [markdown]
# # Cycles and Lists
# # ----------------

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#
# print(i)
i,j,k = 1,2,3
a,b,c = 1,2,3
x,y,z = 1,2,3
a=7

if a<5:
    print('a<5')
elif a==5:
    print('a=5')
elif a==6:
    print('a=6')
else:
    print('a>5')
# Out:
# 0
# 1
# 2
# 3
# 4
# a>5

# %%
i=0
while i < 5:
    if i == 3:
        break
    else:    
        print(i)
        i += 1
print("End of loop")
# Out:
# 0
# 1
# 2
# End of loop

# %%
a = [1, 2, 3, 4, 5.5, 'word']
t = [1, 2, 3, 4, 5.5, 'word']# list
b = {1, 2, 3, 4, 5.5, 'word', 4} # set
c = (1, 2, 3, 4, 5) # tuple
d = {'Student1': 'Name', 
     'cat': 'maine coon', 
     'dog': ['labrador','taksa','sheppard'],
     'fish': 'goldfish'} # dictionary

# %%
print(d['dog'][0])
# Out:
# labrador

# %%
for key, value in d.items():
    print(key, value)
# Out:
# Student1 Name
# cat maine coon
# dog ['labrador', 'taksa', 'sheppard']
# fish goldfish

# %%
num=0
for x in range(3):
    print(num)
    num += x
    print (num)
print(f"Total: {num}")
# Out:
# 0
# 0
# 0
# 1
# 1
# 3
# Total: 3

# %%
c = 'Hello'
